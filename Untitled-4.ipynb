# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib as jb

# %%
df = pd.read_csv("Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
ads = df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df.isna().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
df["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
#encode the categorical data 
df_encoded = pd.get_dummies(df, columns=["Gender"], dtype=int, drop_first=True)
df_encoded.head()
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0  15624510   19            19000          0            1
# 1  15810944   35            20000          0            1
# 2  15668575   26            43000          0            0
# 3  15603246   27            57000          0            0
# 4  15804002   19            76000          0            1

# %%
#selecting the features and target 
x = df_encoded.drop(["User ID", "Purchased"], axis=1)
y = df_encoded["Purchased"]

# %%
x
# Out:
#      Age  EstimatedSalary  Gender_Male
# 0     19            19000            1
# 1     35            20000            1
# 2     26            43000            0
# 3     27            57000            0
# 4     19            76000            1
# ..   ...              ...          ...
# 395   46            41000            0
# 396   51            23000            1
# 397   50            20000            0
# 398   36            33000            1
# 399   49            36000            0
#
# [400 rows x 3 columns]

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train
# Out:
#      Age  EstimatedSalary  Gender_Male
# 3     27            57000            0
# 18    46            28000            1
# 202   39           134000            0
# 250   44            39000            0
# 274   57            26000            0
# ..   ...              ...          ...
# 71    24            27000            0
# 106   26            35000            0
# 270   43           133000            0
# 348   39            77000            1
# 102   32            86000            0
#
# [320 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[-1.06675246, -0.38634438, -1.        ],
#        [ 0.79753468, -1.22993871,  1.        ],
#        [ 0.11069205,  1.853544  , -1.        ],
#        [ 0.60129393, -0.90995465, -1.        ],
#        [ 1.87685881, -1.28811763, -1.        ],
#        [-0.57615058,  1.44629156,  1.        ],
#        [ 0.3069328 , -0.53179168,  1.        ],
#        [ 0.99377543,  0.10817643,  1.        ],
#        [-1.16487283,  0.45724994,  1.        ],
#        [-1.55735433,  0.31180264,  1.        ],
#        [ 1.0918958 ,  0.45724994,  1.        ],
#        [-0.18366908, -0.47361276, -1.        ],
#        [ 0.20881242, -0.32816546,  1.        ],
#        [ 0.3069328 ,  0.28271318, -1.        ],
#        [-1.16487283, -1.57901222,  1.        ],
#        [ 0.11069205,  0.25362372, -1.        ],
#        [ 2.07309956,  1.73718616,  1.        ],
#        [ 0.40505317, -0.18271817,  1.        ],
#        [ 1.4843773 ,  2.11534913, -1.        ],
#        [-0.37990983,  1.21357589,  1.        ],
# ...

# %%
from  sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(x_test)
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 y_pred = knn.predict(x_test)
#       2 y_pred
#
# NameError: name 'knn' is not defined

# %%
y_test[1:6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 y_test[1:6]
#
# NameError: name 'y_test' is not defined

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
accuracy = accuracy_score(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
# ----> 2 accuracy = accuracy_score(y_test, y_pred)
#
# NameError: name 'y_test' is not defined

# %%
acc = accuracy_score(y_test, y_pred)
print(acc*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 acc = accuracy_score(y_test, y_pred)
#       2 print(acc*100)
#
# NameError: name 'y_test' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, xticklabels=['Not Purchased', 'Purchased'], yticklabels=['Not Purchased', 'Purchased'],cmap="binary")
# Out:
# <Axes: >

# %%
import joblib as jb

jb.dump(knn, "knn_model.pkl")
jb.dump(scaler, "scaler.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import joblib as jb
# ----> 3 jb.dump(knn, "knn_model.pkl")
#       4 jb.dump(scaler, "scaler.pkl")
#
# NameError: name 'knn' is not defined

# %%
jb.dump(scaler, "scaler.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 jb.dump(scaler, "scaler.pkl")
#
# NameError: name 'jb' is not defined

# %%
X.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 X.columns
#
# NameError: name 'X' is not defined

# %%
import joblib as jb
import numpy as np
knn = jb.load("knn_model.pkl")
scaler_new = jb.load("scaler.pkl")
age = int(input("Enter your age:"))
salary = int(input("Enter your EstimatedSalary:"))
gender = int(input("Enter your Gender (0 for Female, 1 for Male):"))
new_data = np.array([[age,salary,gender]])
new_data_scaled = scaler_new.transform(new_data)
prediction = knn.predict(new_data_scaled)
if prediction[0] == 1:
    print("The user is likely to purchase the product.")
else:
    print("The user is not likely to purchase the product.")
# Out:
# The user is not likely to purchase the product.
# C:\Users\Anirudha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 dtc = DecisionTreeClassifier()
# ----> 3 dtc.fit(x_train, y_train)
#
# NameError: name 'x_train' is not defined

# %%
y_pred_dtc = dtc.predict(x_test)
y_pred_dtc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_pred_dtc = dtc.predict(x_test)
#       2 y_pred_dtc
#
# NameError: name 'x_test' is not defined
